# %% [markdown]
# # test of YOLOs versions
#
# Polytech SI4
#
# Diane Lingrand Diane.Lingrand@univ-cotedazur.fr
#
# 2024-2025

# %%
# only once, if needed
# !pip install Ultralytics

# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt

# %% [markdown]
# ## choose a YOLO model

# %% [markdown]
# You can browse the Ultralytics <a href="https://docs.ultralytics.com/models/">pages of models</a>.

# %% [markdown]
# Here is an example of large YOLO v5:

# %%
modelv5l = YOLO('yolov5l.pt')
# Out:
# PRO TIP 💡 Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.

# %% [markdown]
# ## choose an image containing different objects

# %%
filename = "/home/lingrand/Ens/MachineLearning/objectDetection/LesCouverts.jpg"
img = plt.imread(filename)
plt.imshow(img)

# %% [markdown]
# ### predict the different objects using the chosen model

# %%
results = modelv5l("/home/lingrand/Ens/MachineLearning/objectDetection/LesCouverts.jpg")
results[0].show()
# Out:
# image 1/1 /home/lingrand/Ens/MachineLearning/objectDetection/LesCouverts.jpg: 480x640 4 knifes, 3 spoons, 72.2ms
# Speed: 3.7ms preprocess, 72.2ms inference, 156.7ms postprocess per image at shape (1, 3, 480, 640)

# %% [markdown]
# ## Compare different models

# %%
# your work
