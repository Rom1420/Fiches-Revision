# %% [markdown]
# <font size=+4><b>TP CNN with MNIST</b></font>
#
# Diane LINGRAND
#
# diane.lingrand@univ-cotedazur.fr
#
# Polytech SI4 - 2024-2025

# %% [markdown]
# # Introduction

# %%
import torch

import random
import numpy as np
import xml.etree.ElementTree as ET
import glob
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from tqdm import tqdm

import keras
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Conv2D, GlobalAveragePooling2D, MaxPooling2D, Flatten, Dropout, BatchNormalization
from sklearn.metrics import accuracy_score, recall_score, confusion_matrix, f1_score, ConfusionMatrixDisplay
from keras.callbacks import EarlyStopping
from keras.preprocessing import image
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from keras.utils import to_categorical

# %% [markdown]
# <font color="green"><b>Question:</b></font> Load the MNIST data as you did in the MLP lab but don't reshape x_train and x_test on a vector: you have to keep the 2D dimensions of images.

# %%
from keras.datasets import mnist

(x_train, y_train), (x_test, y_test) = mnist.load_data()

# %% [markdown]
# # Build your own CNN network

# %% [markdown]
# Start with the simplest CNN: 1 conv2D layer + 1 pooling + 1 dense layer.

# %%
nbClasses = 10

y_train = to_categorical(y_train, nbClasses)
y_test = to_categorical(y_test, nbClasses)

model = Sequential()
model.add(Conv2D(32,(5,5),padding='same',strides=3, activation='relu', input_shape=(28,28,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='same'))

model.add(Conv2D(64,(5,5),padding='same',strides=3, activation='relu', input_shape=(28,28,1)))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding='same'))

model.add(Flatten())
model.add(Dense(nbClasses, activation='softmax'))
model.compile(optimizer='rmsprop',loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# <font color="green"><b>Question:</b></font>Observe the dimension of all inputs and outputs. If the last dimension of input_shape is omitted, you'll get an error message because a tensor of (nbImages, width, height, nbChannels) is mandatory for this Conv2D. We thus need to reshape x_train and x_test to (nbImages, 28, 28, 1).

# %%
model.summary()
# Out:
# Model: "sequential_13"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_24 (Conv2D)              │ (None, 10, 10, 32)     │           832 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_20          │ (None, 10, 10, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_24 (MaxPooling2D) │ (None, 5, 5, 32)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_25 (Conv2D)              │ (None, 2, 2, 64)       │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_21          │ (None, 2, 2, 64)       │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_25 (MaxPooling2D) │ (None, 1, 1, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_13 (Flatten)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_12 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 53,130 (207.54 KB)
#  Trainable params: 52,938 (206.79 KB)
#  Non-trainable params: 192 (768.00 B)

# %% [markdown]
# <font color="green"><b>Question:</b></font> Learn and evaluate this network (performances, history, energy consumption ...). Compare with last week.

# %%
history = model.fit(x_train, y_train, epochs=15, batch_size=64, validation_split=0.2)

test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test accuracy: {test_accuracy * 100} %")
# Out:
# Epoch 1/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 4s 4ms/step - accuracy: 0.8976 - loss: 0.3534 - val_accuracy: 0.9720 - val_loss: 0.0903
# Epoch 2/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9774 - loss: 0.0710 - val_accuracy: 0.9752 - val_loss: 0.0807
# Epoch 3/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9848 - loss: 0.0484 - val_accuracy: 0.9780 - val_loss: 0.0732
# Epoch 4/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9896 - loss: 0.0350 - val_accuracy: 0.9790 - val_loss: 0.0754
# Epoch 5/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9917 - loss: 0.0281 - val_accuracy: 0.9797 - val_loss: 0.0650
# Epoch 6/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9930 - loss: 0.0225 - val_accuracy: 0.9827 - val_loss: 0.0597
# Epoch 7/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9940 - loss: 0.0194 - val_accuracy: 0.9833 - val_loss: 0.0595
# Epoch 8/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9953 - loss: 0.0156 - val_accuracy: 0.9822 - val_loss: 0.0703
# Epoch 9/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9961 - loss: 0.0127 - val_accuracy: 0.9805 - val_loss: 0.0695
# Epoch 10/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9967 - loss: 0.0105 - val_accuracy: 0.9843 - val_loss: 0.0693
# Epoch 11/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9971 - loss: 0.0089 - val_accuracy: 0.9836 - val_loss: 0.0757
# Epoch 12/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9975 - loss: 0.0075 - val_accuracy: 0.9835 - val_loss: 0.0714
# Epoch 13/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.9823 - val_loss: 0.0776
# Epoch 14/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9980 - loss: 0.0061 - val_accuracy: 0.9833 - val_loss: 0.0736
# Epoch 15/15
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.9982 - loss: 0.0059 - val_accuracy: 0.9842 - val_loss: 0.0768
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9807 - loss: 0.0762
# Test accuracy: 0.9850000143051147

# %% [markdown]
# <font color="green"><b>Question:</b></font> Observe that the number of filters and their size correspond to one set of filters you have used in SI3. Display the weights and bias of the network.
# Hints:
# - summary() methode will display the names of all layers.
# - model.get_layer('aName') will return weights and biases.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_1 (Conv2D)               │ (None, 10, 10, 8)      │           208 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 5, 5, 8)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 10)             │         2,010 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,218 (8.66 KB)
#  Trainable params: 2,218 (8.66 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
conv_layer = model.get_layer('conv2d_1')

conv_weights, conv_biases = conv_layer.get_weights()
filter_count = conv_weights.shape[-1]

fig, axs = plt.subplots(1, filter_count, figsize=(20, 5))

for i in range(filter_count):
    axs[i].imshow(conv_weights[:, :, 0, i], cmap='gray')  
    axs[i].set_title(f'Filter {i+1}')

plt.show()

# %% [markdown]
# <font color="green"><b>Question:</b></font> Modify the Conv2D hyperparameters, add more layers (Conv2D and pooling), learn these architectures and search for a better model than the previous one. Publish in slack, channel #si4-deep-learning your best choice of architecture.

# %%
# your work
