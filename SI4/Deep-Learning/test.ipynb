# %%
import numpy as np
import torch
import keras
import math
import matplotlib.pyplot as plt
import matplotlib.lines as mlines
from keras.models import Sequential
from keras.layers import Dense, Activation 
from keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score, accuracy_score, recall_score, classification_report, ConfusionMatrixDisplay, confusion_matrix
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 import numpy as np
#       2 import torch
# ----> 3 import keras
#       4 import math
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'keras'

# %%
model = Sequential()

# Couche de convolution
model.add(
    Conv2D(
        8, (3, 3), padding="same", strides=3, activation="relu", input_shape=(28, 28, 1)
    )
)
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding="same"))

model.add(Conv2D(16, (3, 3), padding="same", strides=3, activation="relu"))
model.add(BatchNormalization())  # Normalisation par lot
model.add(MaxPooling2D(pool_size=(2, 2), strides=2, padding="same"))

model.add(Flatten())

model.add(Dense(nbClasses, activation="softmax"))
model.compile(
    optimizer="rmsprop", loss="categorical_crossentropy", metrics=["accuracy"]
)

# Entraînement du modèle
history = model.fit(x_train, y_train, epochs=15, batch_size=64, validation_split=0.2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model = Sequential()
#       3 # Couche de convolution
#       4 model.add(
#       5     Conv2D(
#       6         8, (3, 3), padding="same", strides=3, activation="relu", input_shape=(28, 28, 1)
#       7     )
#       8 )
#
# NameError: name 'Sequential' is not defined
